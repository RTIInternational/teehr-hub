# %%
import os
from pathlib import Path
import shutil

import teehr

teehr.__version__

# %%
# remove spark-warehouse dir if exists
warehouse_dir = Path(Path.cwd(), 'spark-warehouse')
if warehouse_dir.exists():
    shutil.rmtree(warehouse_dir)

# Define the directory where the Evaluation will be created
test_eval_dir = Path(Path().cwd(), "FIRO_test_evaluation")
if test_eval_dir.exists():
    shutil.rmtree(test_eval_dir)
