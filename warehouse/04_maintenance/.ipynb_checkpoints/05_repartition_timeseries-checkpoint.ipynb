# %%
import os
from pathlib import Path
import shutil

import teehr

teehr.__version__
# Out:
# '0.6.0dev2'

# %%
from spark_session_utils_v06_dev import create_spark_session

# %%
import boto3
session = boto3.Session()
credentials = session.get_credentials()
aws_access_key_id = credentials.access_key
aws_secret_access_key = credentials.secret_key
aws_region = session.region_name
os.environ["AWS_ACCESS_KEY_ID"] = aws_access_key_id
os.environ["AWS_SECRET_ACCESS_KEY"] = aws_secret_access_key
os.environ["AWS_REGION"] = aws_region
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials

# %%
spark = create_spark_session(
    start_spark_cluster=True,
    executor_instances=20,
    executor_memory="16g",
    executor_cores=4,
)
# Out:
# INFO:spark_session_utils_v06_dev:🚀 Creating Spark session: TEEHR Evaluation
# INFO:spark_session_utils_v06_dev:📦 Configuring Spark cluster with container image: None
# INFO:spark_session_utils_v06_dev:🔍 Initial spark namespace from ENV: teehr-hub
# INFO:spark_session_utils_v06_dev:🔍 Connecting to Kubernetes API: https://172.20.0.1:443
# INFO:spark_session_utils_v06_dev:🎯 Executor namespace: teehr-hub
# INFO:spark_session_utils_v06_dev:🔐 Executor service account: spark (in teehr-hub)
# INFO:spark_session_utils_v06_dev:🔐 Using in-cluster authentication
# INFO:spark_session_utils_v06_dev:🔗 Setting driver host to pod IP: 10.0.4.41
# INFO:spark_session_utils_v06_dev:✅ Spark cluster configuration successful!
# INFO:spark_session_utils_v06_dev:   - Executor instances: 20
# INFO:spark_session_utils_v06_dev:   - Executor memory: 16g
# INFO:spark_session_utils_v06_dev:   - Executor cores: 4
# INFO:spark_session_utils_v06_dev:🔑 Using AWS credentials from environment variables
# INFO:spark_session_utils_v06_dev:   - Using long-term credentials
# INFO:spark_session_utils_v06_dev:Configuring Iceberg catalogs...
# INFO:spark_session_utils_v06_dev:⚙️ All settings applied. Creating Spark session...
# INFO:spark_session_utils_v06_dev:🎉 Spark session created successfully!

# %%
# %%time
query = f"""
    DESCRIBE TABLE iceberg.teehr.primary_timeseries
"""
spark.sql(query).show()

# %%
# %%time
query = f"""
    --ALTER TABLE iceberg.teehr.primary_timeseries ADD PARTITION FIELD location_id
    ALTER TABLE iceberg.teehr.primary_timeseries DROP PARTITION FIELD location_id
"""
spark.sql(query).show()

# %%
# %%time
query = f"""
    CALL iceberg.system.rewrite_data_files('teehr.primary_timeseries');
"""
spark.sql(query)

# %%
# %%time
query = f"""
    CALL iceberg.system.expire_snapshots('teehr.primary_timeseries', TIMESTAMP '2025-11-01 12:00:00.000', 1);
"""
spark.sql(query).show()

# %%
# %%time
query = f"""
    SELECT * FROM iceberg.teehr.primary_timeseries.snapshots;
"""
spark.sql(query).show()

# %%
# Secondary Timeseries

# %%
# %%time
query = f"""
    DESCRIBE TABLE iceberg.teehr.secondary_timeseries
"""
spark.sql(query).show()
# Out:
# +--------------------+---------+-------+
# |            col_name|data_type|comment|
# +--------------------+---------+-------+
# |          value_time|timestamp|   NULL|
# |               value|    float|   NULL|
# |           unit_name|   string|   NULL|
# |         location_id|   string|   NULL|
# |              member|   string|   NULL|
# |  configuration_name|   string|   NULL|
# |       variable_name|   string|   NULL|
# |      reference_time|timestamp|   NULL|
# |# Partition Infor...|         |       |
# |          # col_name|data_type|comment|
# |         location_id|   string|   NULL|
# +--------------------+---------+-------+
#
# CPU times: user 0 ns, sys: 2.22 ms, total: 2.22 ms
# Wall time: 98 ms

# %%
# %%time
query = f"""
    -- ALTER TABLE iceberg.teehr.secondary_timeseries ADD PARTITION FIELD location_id
    ALTER TABLE iceberg.teehr.secondary_timeseries DROP PARTITION FIELD location_id
"""
spark.sql(query).show()
# Out:
# ++
# ||
# ++
# ++
#
# CPU times: user 2.37 ms, sys: 238 μs, total: 2.6 ms
# Wall time: 198 ms

# %%
# %%time
query = f"""
    CALL iceberg.system.rewrite_data_files('teehr.secondary_timeseries');
"""
spark.sql(query).show()
# Out:
# +--------------------------+----------------------+---------------------+-----------------------+--------------------------+
# |rewritten_data_files_count|added_data_files_count|rewritten_bytes_count|failed_data_files_count|removed_delete_files_count|
# +--------------------------+----------------------+---------------------+-----------------------+--------------------------+
# |                      8299|                    30|          15709171002|                      0|                         0|
# +--------------------------+----------------------+---------------------+-----------------------+--------------------------+
#
# CPU times: user 15.3 ms, sys: 13.1 ms, total: 28.4 ms
# Wall time: 3min 25s

# %%
# %%time
query = f"""
    SELECT * FROM iceberg.teehr.primary_timeseries.snapshots;
"""
spark.sql(query).show()
# Out:
# +--------------------+-------------------+-------------------+---------+--------------------+--------------------+
# |        committed_at|        snapshot_id|          parent_id|operation|       manifest_list|             summary|
# +--------------------+-------------------+-------------------+---------+--------------------+--------------------+
# |2025-11-01 21:42:...|1120472569719456486|7094973032307620287|  replace|s3://dev-teehr-ic...|{added-data-files...|
# +--------------------+-------------------+-------------------+---------+--------------------+--------------------+
#
# CPU times: user 2.91 ms, sys: 307 μs, total: 3.22 ms
# Wall time: 429 ms

# %%
# %%time
query = f"""
    CALL iceberg.system.expire_snapshots('teehr.secondary_timeseries', TIMESTAMP '2025-11-01 12:00:00.000', 1);
"""
spark.sql(query).show()
# Out:
# +------------------------+-----------------------------------+-----------------------------------+----------------------------+----------------------------+------------------------------+
# |deleted_data_files_count|deleted_position_delete_files_count|deleted_equality_delete_files_count|deleted_manifest_files_count|deleted_manifest_lists_count|deleted_statistics_files_count|
# +------------------------+-----------------------------------+-----------------------------------+----------------------------+----------------------------+------------------------------+
# |                    8410|                                  0|                                  0|                           3|                           2|                             0|
# +------------------------+-----------------------------------+-----------------------------------+----------------------------+----------------------------+------------------------------+
#
# CPU times: user 4.85 ms, sys: 0 ns, total: 4.85 ms
# Wall time: 13.9 s

# %%
spark.stop()
